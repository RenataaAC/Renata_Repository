# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       reg_data.csv
# Book3.csv                  headbrain.csv  sample_pivot.csv
# Canada.xlsx                mic2.xlsx      tips.csv
# Cartwheeldata.csv          mic.xlsx       weight-height.csv

# %%
datafile = 'datasets/Cartwheeldata.csv'

# %%
import pandas as pd

# %%
df = pd.read_csv(datafile)
df.tail(1)
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 24  25   23      F            1       Y             1    65.0      63.0
#
#     CWDistance Complete  CompleteGroup  Score
# 24          67        N              0      3

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
x=df.columns

# %%
x
type(x)
# Out:
# pandas.core.indexes.base.Index

# %%
a=list(x)

# %%
a.sort()
a
# Out:
# ['Age',
#  'CWDistance',
#  'Complete',
#  'CompleteGroup',
#  'Gender',
#  'GenderGroup',
#  'Glasses',
#  'GlassesGroup',
#  'Height',
#  'ID',
#  'Score',
#  'Wingspan']

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
#Loc and iloc

# %%
vars = df.loc[:3, 'Wingspan': 'CompleteGroup']
vars
# Out:
#    Wingspan  CWDistance Complete  CompleteGroup
# 0      61.0          79        Y              1
# 1      60.0          70        Y              1
# 2      64.0          85        Y              1
# 3      63.0          87        Y              1

# %%
vars = df.iloc[2:6, 2:5]
vars
# Out:
#   Gender  GenderGroup Glasses
# 2      F            1       Y
# 3      F            1       N
# 4      M            2       N
# 5      M            2       N
