# %%
print('hi')
# Out:
# hi

# %%
# %ls
# Out:
# datasets/  README.md  requirements.txt  Untitled.ipynb

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       reg_data.csv
# Book3.csv                  headbrain.csv  sample_pivot.csv
# Canada.xlsx                mic2.xlsx      tips.csv
# Cartwheeldata.csv          mic.xlsx       weight-height.csv

# %%
type(3)
# Out:
# int

# %%
type(3.0)
# Out:
# float

# %%
type('ih')
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
type(math.pi)
# Out:
# float

# %%
type('math.pi')
# Out:
# str

# %%
name = 'my_name'

# %%
name
# Out:
# 'my_name'

# %%
name2 = 'renata'

# %%
name2
# Out:
# 'renata'

# %%
name2.find('e')
# Out:
# 1

# %%
name3 = name2 + name
name3
# Out:
# 'renatamy_name'

# %%
x=2
x
# Out:
# 2

# %%
print(x)
# Out:
# 2

# %%
# %pwd
# Out:
# '/home/jovyan'

# %%
# %magic,
# Out:
# UsageError: Line magic function `%magic,` not found.

# %%
a_list = [2 , 3, 4.0, 'a_name', True]

# %%
a_list
# Out:
# [2, 3, 4.0, 'a_name', True]

# %%
a_list[2]
# Out:
# 4.0

# %%
type(a_list)
# Out:
# list

# %%
b_list = [2,3,4,5]

# %%
b_list
# Out:
# [2, 3, 4, 5]

# %%
sum(b_list)
# Out:
# 14

# %%
average= (sum(b_list)/len(b_list))
average
# Out:
# 3.5

# %%
len(b_list)
# Out:
# 4

# %%
x=6
y=7
if x < y:
    print('x is less than y')
else:
    print('x is greater than y')
# Out:
# x is less than y

# %%
x=6
y=7
if x < y:
    print('{} is less than {}'.format(x,y))
else:
    print('x is greater than y')
# Out:
# 6 is less than 7

# %%
None

# %%
type(None)
# Out:
# NoneType

# %%
a_list
# Out:
# [2, 3, 4.0, 'a_name', True]

# %%
for i in a_list:
    print(i)
# Out:
# 2
# 3
# 4.0
# a_name
# True

# %%
for i in a_list:
    print(i, '\t', type(i))
# Out:
# 2 	 <class 'int'>
# 3 	 <class 'int'>
# 4.0 	 <class 'float'>
# a_name 	 <class 'str'>
# True 	 <class 'bool'>

# %%
'\t' --> son espacios
# Out:
#   File "/tmp/ipykernel_61/3717455448.py", line 1
#     '\t' --> son espacios
#            ^
# SyntaxError: invalid syntax

# %%
str_list = ['Done', 'Ctwo', 'Bthree', 'Afour']
str_list
# Out:
# ['Done', 'Ctwo', 'Bthree', 'Afour']

# %%
str_list.sort()
str_list
# Out:
# ['Afour', 'Bthree', 'Ctwo', 'Done']

# %%
str_list
# Out:
# ['Afour', 'Bthree', 'Ctwo', 'Done']

# %%
str_list[0:2]
# Out:
# ['Afour', 'Bthree']

# %%
str_list[0:4]
# Out:
# ['Afour', 'Bthree', 'Ctwo', 'Done']

# %%
str_list[-1]
# Out:
# 'Done'

# %%
str_list[:-1]
# Out:
# ['Afour', 'Bthree', 'Ctwo']

# %%
import numpy as np

# %%
a = [1,2,3,4]
np.mean(a)
# Out:
# 2.5

# %%
a = np.dot([2j, 3j], [2,3j])
a
# Out:
# (-9+4j)

# %%
b = np.dot(3,4)
print(b)
type(b)
# Out:
# 12
# numpy.int64
